# %%
#favorite resource for run-of-the-mill pandas (+general ML)
#https://mlcourse.ai/articles/topic1-exploratory-data-analysis-with-pandas/
# Out:
# ...
#      |████████████████████████████████| 28.2MB 286kB/s eta 0:00:01
# ...
# WARNING: You are using pip version 19.3.1; however, version 20.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
# !pwd
# Out:
# /tf/github/beetle-vision

# %%
rbi_csv = pd.read_csv(os.getcwd()+ '/labels/master_rbi.csv')

# %%
print(rbi_csv.shape)
# Out:
# (4074, 8)

# %%
print(rbi_csv.columns)
# Out:
# Index(['Family:', 'Subfamily:', 'Country:', 'Province:', 'Genus:', 'Species:',
#        'View:', 'Filename:'],
#       dtype='object')

# %%
print(rbi_csv.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4074 entries, 0 to 4073
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Family:     4074 non-null   object
#  1   Subfamily:  4074 non-null   object
#  2   Country:    4074 non-null   object
#  3   Province:   4074 non-null   object
#  4   Genus:      4074 non-null   object
#  5   Species:    4074 non-null   object
#  6   View:       4074 non-null   object
#  7   Filename:   4074 non-null   object
# dtypes: object(8)
# memory usage: 254.8+ KB
# None

# %%
rbi_csv.head()
# Out:
#        Family: Subfamily:           Country: Province:       Genus:  \
# 0  Anthribidae          /  Equatorial Guinea         /  Phaeotragus
# 1  Anthribidae          /  Equatorial Guinea         /  Phaeotragus
# 2  Anthribidae          /         Madagascar         /  Tophroderes
# 3    Brentidae          /          Indonesia   Sumatra  Eutrachelus
# 4    Brentidae          /          Indonesia   Sumatra  Eutrachelus
#
#     Species:    View:  Filename:
# 0      gigas   Dorsal  rbi_1.jpg
# 1      gigas  Lateral  rbi_2.jpg
# 2  phrenatus   Dorsal  rbi_3.jpg
# 3  temmincki   Dorsal  rbi_4.jpg
# 4  temmincki   Dorsal  rbi_5.jpg

# %%
rbi_csv.describe()
# Out:
#              Family: Subfamily:   Country: Province:    Genus:   Species:  \
# count           4074       4074       4074      4074      4074       4074
# unique            20         14        129       470       818       1600
# top     Scarabaeidae          /  Indonesia         /  Phanaeus  sumptuosa
# freq            2080       1027        288      1616       187         23
#
#          View:     Filename:
# count     4074          4074
# unique      18          4074
# top     Dorsal  rbi_3264.jpg
# freq      2982             1

# %%
rbi_csv['Family:'].value_counts(normalize=True)
# Out:
# Scarabaeidae       0.510555
# Cerambycidae       0.237359
# Lucanidae          0.085420
# Buprestidae        0.071183
# Carabidae          0.037064
# Cicindelidae       0.027491
# Geotrupidae        0.018900
# Chrysomelidae      0.002209
# Silphidae          0.001718
# Curculionidae      0.001473
# Meloidae           0.001227
# Dytiscidae         0.000736
# Brentidae          0.000736
# Trictenotomidae    0.000736
# Elateridae         0.000736
# Cleridae           0.000736
# Anthribidae        0.000736
# Lycidae            0.000491
# Lampyridae         0.000245
# Zopheridae         0.000245
# Name: Family:, dtype: float64

# %%
rbi_csv['View:'].value_counts(normalize=True)
# Out:
# Dorsal               0.731959
# Lateral              0.143839
# Ventral              0.039519
# Frontal              0.036328
# Lateral Head         0.031173
# Dorsal Head          0.008100
# Labels               0.002700
# Paramera lateral     0.002455
# Paramera dorsal      0.001227
# Pygidium             0.000491
# Paramera frontal     0.000491
# Ventral fore legs    0.000245
# Prosternum           0.000245
# Antenna              0.000245
# Scutellum            0.000245
# Ventral abdomen      0.000245
# Tibia claws          0.000245
# Ventral Head         0.000245
# Name: View:, dtype: float64

# %%
rbi_csv['Country:'].value_counts(normalize=True)
# Out:
# Indonesia                                0.070692
# Brazil                                   0.066028
# Congo, The Democratic Republic of the    0.063574
# Australia                                0.063328
# Madagascar                               0.052283
#                                            ...
# Vanuatu                                  0.000245
# Cape Verde                               0.000245
# Suriname                                 0.000245
# Djibouti                                 0.000245
# Tunisia                                  0.000245
# Name: Country:, Length: 129, dtype: float64

# %%
pd.crosstab(rbi_csv['Family:'], rbi_csv['Country:'])
# Out:
# Country:          /  Algeria  Angola  Argentina  Armenia  Australia  Belgium  \
# Family:
# Anthribidae       0        0       0          0        0          0        0
# Brentidae         0        0       0          0        0          0        0
# Buprestidae      13        2       0          2        0         75        0
# Carabidae        11        4       0          0        1         12        0
# Cerambycidae     66        4       1         19        0         40        1
# Chrysomelidae     2        0       0          0        0          0        0
# Cicindelidae      5        0       0          0        0          2        0
# Cleridae          0        0       0          0        0          0        0
# Curculionidae     4        0       0          0        0          0        0
# Dytiscidae        0        0       0          0        0          0        0
# Elateridae        0        0       0          0        0          0        0
# ...
